# %%
# Starting with importing the nessery ibraries:
## Data manipulating libraries:
import numpy as np # Numpy for mathmatic and linear algebra operations.
import pandas as pd # Pandas to hold and manipulate the data.
pd.set_option('display.float_format', '{:.2f}'.format) # To display only 2 float digits.
pd.set_option('display.max_columns', 100) # To display number of columns up to 100 column everytime we take a look at the data.
## Data visualization libraries:
import matplotlib.pyplot as plt # For low level and simple visualizations.
# To get the charts appearing within the notebook.
# %matplotlib inline
import seaborn as sns # For hiegher level visualization.
sns.set_style('darkgrid') # Setting visualization grid style to be dark.
sns.set(font_scale = 1.5) # Setting the font scale of the visualization.
import plotly.express as px # Plotly express for high level and interactive visualizations.
from plotly.subplots import make_subplots # To hold plotly subplots.
import plotly.graph_objs as go # For plotly plots within the suplots

import warnings
warnings.filterwarnings("ignore") # To ignore any warnings that may spoil the look of our notebook.

# %%
d1 = pd.read_csv("./tmdb-movies (1).csv") # Reading credits data.
d1.head() # showing a sample of credits data.
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610       32.99  150000000  1513528810
# 1   76341  tt1392190       28.42  150000000   378436354
# 2  262500  tt2908446       13.11  110000000   295238201
# 3  140607  tt2488496       11.17  200000000  2068178225
# 4  168259  tt2820852        9.34  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
d2 = pd.read_csv("./tmdb-movies (2).csv") # Reading movies data.
d2.head() # showing a sample of movies data.
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610       32.99  150000000  1513528810
# 1   76341  tt1392190       28.42  150000000   378436354
# 2  262500  tt2908446       13.11  110000000   295238201
# 3  140607  tt2488496       11.17  200000000  2068178225
# 4  168259  tt2820852        9.34  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
d1.rename(columns={'movie_id':'id'}, inplace=True) # renaming movie_id column to be just id to..
df = d2.merge( d1,on= 'id') # join the two data sets on.
df.head() # showing a sample of the joined dataset.
# Out:
#        id  imdb_id_x  popularity_x   budget_x   revenue_x  \
# 0  135397  tt0369610         32.99  150000000  1513528810
# 1   76341  tt1392190         28.42  150000000   378436354
# 2  262500  tt2908446         13.11  110000000   295238201
# 3  140607  tt2488496         11.17  200000000  2068178225
# 4  168259  tt2820852          9.34  190000000  1506249360
#
#                original_title_x  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                               cast_x  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                           homepage_x        director_x  \
# ...

# %%
df.info() # showing some information about then ew dataset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10868 entries, 0 to 10867
# Data columns (total 41 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      10868 non-null  int64
#  1   imdb_id_x               10858 non-null  object
#  2   popularity_x            10868 non-null  float64
#  3   budget_x                10868 non-null  int64
#  4   revenue_x               10868 non-null  int64
#  5   original_title_x        10868 non-null  object
#  6   cast_x                  10792 non-null  object
#  7   homepage_x              2936 non-null   object
#  8   director_x              10824 non-null  object
#  9   tagline_x               8044 non-null   object
#  10  keywords_x              9375 non-null   object
#  11  overview_x              10864 non-null  object
#  12  runtime_x               10868 non-null  int64
#  13  genres_x                10845 non-null  object
# ...

# %%
df.keywords_x # Takaing a look of genres column to how much cleaning it needs.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.keywords_x
#
# NameError: name 'df' is not defined
